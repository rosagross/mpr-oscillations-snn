# %% [markdown]
# # Module 2.4: SNN-MPR Comparison
#
# Works with SNN simulations for (Vt, Vr) = (1000, -1000), (Vt, Vr) = (85, -85) and (Vt, Vr) = (30, -65)
#
# New data frame to
# - merge optimized_amplitude and rand_init files wrt target frequencies
# - save the full parameter set
# - save the full optimization information
# - save error (MPR frequency - SNN frequency)/target_frequency *100

# %% [markdown]
# SNN files are available at
#
# https://www.dropbox.com/scl/fo/vv7lx16wdb3tcnn125ar2/ACWugwhwcVYstGZ81TcVIWQ?rlkey=xo57pfu62afvy75ts7makyr11&e=1&st=3x9bk27n&dl=0

# %% [markdown]
# ## 0.1 Import all built-in packages.

# %%
# Import necessary packages
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.signal import find_peaks
import numpy as np
import pandas as pd
import pickle
import zipfile
import seaborn as sns
from pathlib import Path

# %%
### Compute Power Spectrum of simulated MPR, output data.

def compute_PS_MPR(sol):
    dt_min = np.min(np.diff(sol.t))
    Fs = int(1000 / np.min(np.diff(sol.t)))
    sampling_rate_max = 1 / dt_min             # maximum sampling frequency (Hz)
    t_regular = np.arange(0, sol.t[-1], dt_min)
    y_regular = sol.sol(t_regular)
    # # Compute the Fourier Transform of the signal R_E
    sign = y_regular[0, int((t_regular[-1]-1000)/dt_min):int(t_regular[-1]/dt_min)]
    fft_values = np.fft.fft(sign)
    # # Compute the Power Spectrum (Magnitude squared of FFT)
    power_spectrum = np.abs(fft_values) ** 2
    # # Create the frequency axis
    frequencies = np.fft.fftfreq(len(sign), 1 / Fs)
    # Only keep the positive frequencies (due to symmetry)
    positive_freq_indices = frequencies > 0
    frequencies_exc = frequencies[positive_freq_indices]
    power_spectrum_exc = power_spectrum[positive_freq_indices]

    # # Compute the Fourier Transform of the signal R_I
    sign = y_regular[0, int((t_regular[-1]-1000)/dt_min):int(t_regular[-1]/dt_min)]
    fft_values = np.fft.fft(sign)
    # # Compute the Power Spectrum (Magnitude squared of FFT)
    power_spectrum = np.abs(fft_values) ** 2
    # # Create the frequency axis
    frequencies = np.fft.fftfreq(len(sign), 1 / Fs)
    # Only keep the positive frequencies (due to symmetry)
    positive_freq_indices = frequencies > 0
    frequencies_inh = frequencies[positive_freq_indices]
    power_spectrum_inh = power_spectrum[positive_freq_indices]

    return frequencies_exc, frequencies_inh, power_spectrum_exc, power_spectrum_inh

def compute_PS_SNN(data_SNN, cutoff_max_freq = 200):

    # get the frequency and power spectrum data
    freq_SNN_exc = data_SNN['fw_exc'][0:cutoff_max_freq]
    freq_SNN_inh = data_SNN['fw_inh'][0:cutoff_max_freq]

    PS_SNN_exc = data_SNN['fA_exc'][0:cutoff_max_freq]
    PS_SNN_inh = data_SNN['fA_inh'][0:cutoff_max_freq]

    PS_SNN_exc_scaled = PS_SNN_exc - np.min(PS_SNN_exc)
    PS_SNN_exc_scaled /= np.max(PS_SNN_exc_scaled)

    PS_SNN_inh_scaled = PS_SNN_inh - np.min(PS_SNN_inh)
    PS_SNN_inh_scaled /= np.max(PS_SNN_inh_scaled)

    return freq_SNN_exc, freq_SNN_inh, PS_SNN_exc_scaled, PS_SNN_inh_scaled


### Find Peaks of Power Spectrum 
def find_peaks_PS(frequencies, power_spectrum, target_freq, isitrange=True):
    if not isitrange:
        peak_frequencies = frequencies[np.argmax(power_spectrum)]
        return peak_frequencies
    else:
        ### compute the error between the target frequency and the peak frequency
        peak_frequencies = frequencies[np.argmax(power_spectrum)]

        ### compute the error in the range of the target frequency
        # Find all local maxima first
        vmin, vmax = target_freq *0, target_freq*1.95

        peaks = find_peaks(power_spectrum)

        # Filter by value range
        mask = (frequencies[peaks[0]] >= vmin) & (frequencies[peaks[0]] <= vmax)
        filtered_peaks = peaks[0][mask]
        if len(filtered_peaks) > 0:
            peak_frequencies = frequencies[filtered_peaks[np.argmax(power_spectrum[filtered_peaks])]]
        else:
            peak_frequencies = 0.0  # or some other default value if no peaks found in range

    return peak_frequencies

# %% [markdown]
# # 1.1 Read optimized parameters

# %%
list_cols = {0:'a',
            1: 'b',
            2: 'c',
            3: 'ep_delta',
            4: 'ep_eta',
            5: 'ep_alpha',
            6: 'ep_beta',
            7: 'ep_ujump',
            8: 'ep_input',
            9: 'ip_delta',
            10: 'ip_eta',
            11: 'ip_alpha',
            12: 'ip_beta',
            13: 'ip_ujump',
            14: 'ip_input',
            15: 'cp_ee',
            16: 'cp_ii',
            17: 'cp_ie',
            18: 'cp_ei',
            19: 'sp_ge',
            20: 'sp_gi',
            21: 'sp_sejump',
            22: 'sp_sijump',
            23: 'sp_reve',
            24: 'sp_revi',
            25: 'sp_tause',
            26: 'sp_tausi',
            27: 'f_target',
            28:'fmax_MPR_exc',
            29:'fmax_SNN_exc',
            30:'error_freq_exc',
            31:'fmax_MPR_inh',
            32:'fmax_SNN_inh',
            33:'error_freq_inh',
            34: 'parameter_set_file',
            35: 'param_ID'
             }

# create data frame from list_cols
df = pd.DataFrame(columns=list_cols.values())

# %% [markdown]
# # 1.2 Read data, compute error, define the list

# %%
target_freq = 6 # Target frequency in Hz
from pathlib import PurePosixPath
import re

def _numeric_suffix_key(fname: str):
    m = re.search(r'(\d+)(?=\.pkl$)', fname)
    return int(m.group(1)) if m else float('inf')

for parameter_set_file in ['optimized_frequencies', 'rand_init_optimization_results']:

    data_parameter_set = pd.read_csv(parameter_set_file + '.csv')

    # path to SNN
    variationvrvt = 'Variation_VR_1000_VT_1000'
    # variationvrvt = 'Variation_VR_85_VT_85'
    # variationvrvr = 'Variation_VR_65_VT_30'
    zip_path = Path('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_SNN_from_'+parameter_set_file+'/'+variationvrvt)
    zip_files = list(zip_path.glob("*.zip"))
    # group the ones starting with SNN_Data_Directory_Target+str(target_freq)
    zip_files_target = [z for z in zip_files if f'SNN_Data_Directory_Target_{target_freq}' in z.name]
    print(f"SNN Found {len(zip_files_target)} zip files for target frequency {target_freq} Hz.")
    print(zip_files_target)

    # path to MPR
    zip_path_MPR = Path('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_MPR_from_'+parameter_set_file)
    zip_files_MPR = list(zip_path_MPR.glob("*.zip"))
    zip_files_MPR_target = [z for z in zip_files_MPR if f'MPR_Data_Directory_Target_{target_freq}' in z.name]
    print(f"MPR Found {len(zip_files_MPR_target)} zip files for target frequency {target_freq} Hz.")
    print(zip_files_MPR_target)

    
    # # Open the zip file
    with zipfile.ZipFile(zip_files_MPR_target[0], 'r') as zip_file_MPR,\
        zipfile.ZipFile(zip_files_target[0], 'r') as zip_file:
        print('loaded', zip_file_MPR.namelist())
        print('loaded', zip_file.namelist())

        # pkl_file_names_SNN = [PurePosixPath(name).name for name in zip_file.namelist() if name.endswith('.pkl')]
        # pkl_file_names_MPR = [PurePosixPath(name).name for name in zip_file_MPR.namelist() if name.endswith('.pkl')]
        pkl_file_names_SNN = sorted([PurePosixPath(n).name for n in zip_file.namelist() if n.endswith('.pkl')], key=_numeric_suffix_key)
        # pkl_file_names_MPR = sorted([PurePosixPath(n).name for n in zip_file_MPR.namelist() if n.endswith('.pkl')], key=_numeric_suffix_key)
        pkl_file_names_MPR = sorted([n for n in zip_file_MPR.namelist() if n.endswith('.pkl')], key=_numeric_suffix_key) # it is because the folder zipped in OS


        # Open the pickle file inside the zip
        for i in range(len(data_parameter_set[data_parameter_set['desired_frequency']==target_freq])):
            param_fit_index = data_parameter_set.index[data_parameter_set['desired_frequency']==target_freq][i]
            with zip_file.open(pkl_file_names_SNN[i]) as pkl_file:
                data_SNN = pickle.load(pkl_file)
            with zip_file_MPR.open(pkl_file_names_MPR[i]) as pkl_file:
                data_MPR = pickle.load(pkl_file)

            # compute power spectrum for MPR
            frequencies_exc_MPR, frequencies_inh_MPR, power_spectrum_exc_MPR, power_spectrum_inh_MPR = compute_PS_MPR(data_MPR['solution'])
            # compute power spectrum for SNN
            frequencies_exc_SNN, frequencies_inh_SNN, power_spectrum_exc_SNN, power_spectrum_inh_SNN = compute_PS_SNN(data_SNN)
            # compute peak frequencies
            peak_freq_MPR_exc = find_peaks_PS(frequencies_exc_MPR, power_spectrum_exc_MPR, target_freq, isitrange=True)
            peak_freq_SNN_exc = find_peaks_PS(frequencies_exc_SNN, power_spectrum_exc_SNN, target_freq, isitrange=True)
            peak_freq_MPR_inh = find_peaks_PS(frequencies_inh_MPR, power_spectrum_inh_MPR, target_freq, isitrange=True)
            peak_freq_SNN_inh = find_peaks_PS(frequencies_inh_SNN, power_spectrum_inh_SNN, target_freq, isitrange=True)
            # compute the error between the target frequency and the peak frequency
            error_MPR_SNN_exc = (peak_freq_MPR_exc - peak_freq_SNN_exc)/target_freq * 100
            error_MPR_SNN_inh = (peak_freq_MPR_inh - peak_freq_SNN_inh)/target_freq * 100


            list_params_compare_freq = list(data_SNN['parameters'].values())
            list_params_compare_freq.append(target_freq)
            list_params_compare_freq.append(peak_freq_MPR_exc)
            list_params_compare_freq.append(peak_freq_SNN_exc)
            list_params_compare_freq.append(error_MPR_SNN_exc)
            list_params_compare_freq.append(peak_freq_MPR_inh)
            list_params_compare_freq.append(peak_freq_SNN_inh)
            list_params_compare_freq.append(error_MPR_SNN_inh)
            list_params_compare_freq.append(parameter_set_file)
            list_params_compare_freq.append(param_fit_index)
            df.loc[len(df)] = list_params_compare_freq

df.head()
print(len(df))
dataframe_file_name = '/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/param_freq_target_'+variationvrvt+'_'+str(target_freq)+'.csv'
df.to_csv(dataframe_file_name)
# Out:
# SNN Found 2 zip files for target frequency 6 Hz.
# [PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_SNN_from_optimized_frequencies/Variation_VR_1000_VT_1000/SNN_Data_Directory_Target_6_20260402081533.zip'), PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_SNN_from_optimized_frequencies/Variation_VR_1000_VT_1000/SNN_Data_Directory_Target_60_20260402101717.zip')]
# MPR Found 2 zip files for target frequency 6 Hz.
# [PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_MPR_from_optimized_frequencies/MPR_Data_Directory_Target_6.zip'), PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_MPR_from_optimized_frequencies/MPR_Data_Directory_Target_60.zip')]
# loaded ['MPR_Data_Directory_Target_6/', 'MPR_Data_Directory_Target_6/data_MPR_5.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_42.png', 'MPR_Data_Directory_Target_6/figure_MPR_56.png', 'MPR_Data_Directory_Target_6/data_MPR_59.pkl', 'MPR_Data_Directory_Target_6/data_MPR_65.pkl', 'MPR_Data_Directory_Target_6/data_MPR_64.pkl', 'MPR_Data_Directory_Target_6/data_MPR_58.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_57.png', 'MPR_Data_Directory_Target_6/figure_MPR_43.png', 'MPR_Data_Directory_Target_6/data_MPR_4.pkl', 'MPR_Data_Directory_Target_6/data_MPR_6.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_55.png', 'MPR_Data_Directory_Target_6/figure_MPR_41.png', 'MPR_Data_Directory_Target_6/data_MPR_66.pkl', 'MPR_Data_Directory_Target_6/data_MPR_67.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_40.png', 'MPR_Data_Directory_Target_6/figure_MPR_54.png', 'MPR_Data_Directory_Target_6/data_MPR_7.pkl', 'MPR_Data_Directory_Target_6/data_MPR_3.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_50.png', 'MPR_Data_Directory_Target_6/figure_MPR_44.png', 'MPR_Data_Directory_Target_6/data_MPR_63.pkl', 'MPR_Data_Directory_Target_6/data_MPR_62.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_45.png', 'MPR_Data_Directory_Target_6/figure_MPR_51.png', 'MPR_Data_Directory_Target_6/data_MPR_2.pkl', 'MPR_Data_Directory_Target_6/data_MPR_0.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_47.png', 'MPR_Data_Directory_Target_6/figure_MPR_53.png', 'MPR_Data_Directory_Target_6/figure_MPR_9.png', 'MPR_Data_Directory_Target_6/data_MPR_60.pkl', 'MPR_Data_Directory_Target_6/data_MPR_48.pkl', 'MPR_Data_Directory_Target_6/data_MPR_49.pkl', 'MPR_Data_Directory_Target_6/data_MPR_61.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_8.png', 'MPR_Data_Directory_Target_6/figure_MPR_52.png', 'MPR_Data_Directory_Target_6/figure_MPR_46.png', 'MPR_Data_Directory_Target_6/data_MPR_1.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_21.png', 'MPR_Data_Directory_Target_6/figure_MPR_35.png', 'MPR_Data_Directory_Target_6/data_MPR_12.pkl', 'MPR_Data_Directory_Target_6/data_MPR_13.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_34.png', 'MPR_Data_Directory_Target_6/figure_MPR_20.png', 'MPR_Data_Directory_Target_6/figure_MPR_36.png', 'MPR_Data_Directory_Target_6/figure_MPR_22.png', 'MPR_Data_Directory_Target_6/data_MPR_39.pkl', 'MPR_Data_Directory_Target_6/data_MPR_11.pkl', 'MPR_Data_Directory_Target_6/data_MPR_10.pkl', 'MPR_Data_Directory_Target_6/data_MPR_38.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_23.png', 'MPR_Data_Directory_Target_6/figure_MPR_37.png', 'MPR_Data_Directory_Target_6/figure_MPR_33.png', 'MPR_Data_Directory_Target_6/figure_MPR_27.png', 'MPR_Data_Directory_Target_6/data_MPR_14.pkl', 'MPR_Data_Directory_Target_6/data_MPR_28.pkl', 'MPR_Data_Directory_Target_6/data_MPR_29.pkl', 'MPR_Data_Directory_Target_6/data_MPR_15.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_26.png', 'MPR_Data_Directory_Target_6/figure_MPR_32.png', 'MPR_Data_Directory_Target_6/figure_MPR_24.png', 'MPR_Data_Directory_Target_6/figure_MPR_30.png', 'MPR_Data_Directory_Target_6/figure_MPR_18.png', 'MPR_Data_Directory_Target_6/data_MPR_17.pkl', 'MPR_Data_Directory_Target_6/data_MPR_16.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_19.png', 'MPR_Data_Directory_Target_6/figure_MPR_31.png', 'MPR_Data_Directory_Target_6/figure_MPR_25.png', 'MPR_Data_Directory_Target_6/figure_MPR_28.png', 'MPR_Data_Directory_Target_6/figure_MPR_14.png', 'MPR_Data_Directory_Target_6/data_MPR_27.pkl', 'MPR_Data_Directory_Target_6/data_MPR_33.pkl', 'MPR_Data_Directory_Target_6/data_MPR_32.pkl', 'MPR_Data_Directory_Target_6/data_MPR_26.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_15.png', 'MPR_Data_Directory_Target_6/figure_MPR_29.png', 'MPR_Data_Directory_Target_6/figure_MPR_17.png', 'MPR_Data_Directory_Target_6/data_MPR_18.pkl', 'MPR_Data_Directory_Target_6/data_MPR_30.pkl', 'MPR_Data_Directory_Target_6/data_MPR_24.pkl', 'MPR_Data_Directory_Target_6/data_MPR_25.pkl', 'MPR_Data_Directory_Target_6/data_MPR_31.pkl', 'MPR_Data_Directory_Target_6/data_ ...
# loaded ['visual_SNN_14.png', 'data_SNN_1.pkl', 'visual_SNN_5.png', 'data_SNN_9.pkl', 'data_SNN_56.pkl', 'data_SNN_13.pkl', 'data_SNN_65.pkl', 'data_SNN_10.pkl', 'visual_SNN_18.png', 'visual_SNN_1.png', 'visual_SNN_13.png', 'data_SNN_58.pkl', 'visual_SNN_35.png', 'data_SNN_53.pkl', 'data_SNN_60.pkl', 'visual_SNN_61.png', 'visual_SNN_45.png', 'visual_SNN_6.png', 'data_SNN_51.pkl', 'data_SNN_42.pkl', 'visual_SNN_38.png', 'data_SNN_49.pkl', 'visual_SNN_9.png', 'data_SNN_50.pkl', 'visual_SNN_53.png', 'data_SNN_67.pkl', 'data_SNN_8.pkl', 'data_SNN_64.pkl', 'visual_SNN_39.png', 'visual_SNN_34.png', 'visual_SNN_37.png', 'visual_SNN_59.png', 'visual_SNN_57.png', 'data_SNN_2.pkl', 'visual_SNN_49.png', 'data_SNN_36.pkl', 'visual_SNN_64.png', 'visual_SNN_55.png', 'visual_SNN_7.png', 'visual_SNN_51.png', 'visual_SNN_17.png', 'data_SNN_3.pkl', 'data_SNN_27.pkl', 'data_SNN_4.pkl', 'data_SNN_20.pkl', 'data_SNN_38.pkl', 'visual_SNN_43.png', 'visual_SNN_24.png', 'visual_SNN_66.png', 'visual_SNN_19.png', 'visual_SNN_4.png', 'data_SNN_35.pkl', 'visual_SNN_10.png', 'visual_SNN_52.png', 'visual_SNN_26.png', 'data_SNN_32.pkl', 'visual_SNN_29.png', 'visual_SNN_40.png', 'data_SNN_11.pkl', 'data_SNN_66.pkl', 'data_SNN_5.pkl', 'visual_SNN_12.png', 'data_SNN_57.pkl', 'visual_SNN_48.png', 'data_SNN_44.pkl', 'data_SNN_47.pkl', 'data_SNN_17.pkl', 'data_SNN_28.pkl', 'data_SNN_43.pkl', 'data_SNN_12.pkl', 'visual_SNN_33.png', 'visual_SNN_11.png', 'data_SNN_22.pkl', 'visual_SNN_25.png', 'data_SNN_41.pkl', 'visual_SNN_62.png', 'data_SNN_37.pkl', 'data_SNN_33.pkl', 'visual_SNN_58.png', 'data_SNN_52.pkl', 'visual_SNN_32.png', 'data_SNN_62.pkl', 'visual_SNN_41.png', 'data_SNN_39.pkl', 'visual_SNN_27.png', 'data_SNN_46.pkl', 'data_SNN_55.pkl', 'data_SNN_19.pkl', 'visual_SNN_63.png', 'data_SNN_34.pkl', 'data_SNN_23.pkl', 'data_SNN_63.pkl', 'data_SNN_30.pkl', 'data_SNN_25.pkl', 'data_SNN_29.pkl', 'visual_SNN_56.png', 'visual_SNN_8.png', 'visual_SNN_15.png', 'data_SNN_14.pkl', 'data_SNN_16.pkl', 'visual_SNN_28.png', 'data_SNN_6.pkl', 'visual_SNN_23.png', 'visual_SNN_3.png', 'data_SNN_15.pkl', 'visual_SNN_50.png', 'visual_SNN_36.png', 'visual_SNN_21.png', 'data_SNN_31.pkl', 'visual_SNN_42.png', 'visual_SNN_20.png', 'visual_SNN_31.png', 'data_SNN_48.pkl', 'visual_SNN_30.png', 'data_SNN_7.pkl', 'visual_SNN_65.png', 'visual_SNN_46.png', 'visual_SNN_2.png', 'data_SNN_61.pkl', 'visual_SNN_16.png', 'data_SNN_59.pkl', 'data_SNN_54.pkl', 'data_SNN_45.pkl', 'data_SNN_40.pkl', 'visual_SNN_0.png', 'visual_SNN_44.png', 'data_SNN_18.pkl', 'data_SNN_24.pkl', 'visual_SNN_22.png', 'visual_SNN_60.png', 'data_SNN_26.pkl', 'visual_SNN_54.png', 'visual_SNN_47.png', 'visual_SNN_67.png', 'data_SNN_0.pkl', 'data_SNN_21.pkl']
# SNN Found 2 zip files for target frequency 6 Hz.
# [PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_SNN_from_rand_init_optimization_results/Variation_VR_1000_VT_1000/SNN_Data_Directory_Target_60_20260402005253.zip'), PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_SNN_from_rand_init_optimization_results/Variation_VR_1000_VT_1000/SNN_Data_Directory_Target_6_20260401230840.zip')]
# MPR Found 2 zip files for target frequency 6 Hz.
# [PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_MPR_from_rand_init_optimization_results/MPR_Data_Directory_Target_6.zip'), PosixPath('/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/Raw_MPR_from_rand_init_optimization_results/MPR_Data_Directory_Target_60.zip')]
# loaded ['MPR_Data_Directory_Target_6/', 'MPR_Data_Directory_Target_6/data_MPR_5.pkl', 'MPR_Data_Directory_Target_6/data_MPR_4.pkl', 'MPR_Data_Directory_Target_6/data_MPR_6.pkl', 'MPR_Data_Directory_Target_6/data_MPR_7.pkl', 'MPR_Data_Directory_Target_6/data_MPR_3.pkl', 'MPR_Data_Directory_Target_6/data_MPR_2.pkl', 'MPR_Data_Directory_Target_6/data_MPR_0.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_9.png', 'MPR_Data_Directory_Target_6/figure_MPR_8.png', 'MPR_Data_Directory_Target_6/data_MPR_1.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_21.png', 'MPR_Data_Directory_Target_6/data_MPR_12.pkl', 'MPR_Data_Directory_Target_6/data_MPR_13.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_20.png', 'MPR_Data_Directory_Target_6/figure_MPR_22.png', 'MPR_Data_Directory_Target_6/data_MPR_11.pkl', 'MPR_Data_Directory_Target_6/data_MPR_10.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_23.png', 'MPR_Data_Directory_Target_6/data_MPR_14.pkl', 'MPR_Data_Directory_Target_6/data_MPR_15.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_18.png', 'MPR_Data_Directory_Target_6/data_MPR_17.pkl', 'MPR_Data_Directory_Target_6/data_MPR_16.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_19.png', 'MPR_Data_Directory_Target_6/figure_MPR_14.png', 'MPR_Data_Directory_Target_6/figure_MPR_15.png', 'MPR_Data_Directory_Target_6/figure_MPR_17.png', 'MPR_Data_Directory_Target_6/data_MPR_18.pkl', 'MPR_Data_Directory_Target_6/data_MPR_19.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_16.png', 'MPR_Data_Directory_Target_6/figure_MPR_12.png', 'MPR_Data_Directory_Target_6/data_MPR_21.pkl', 'MPR_Data_Directory_Target_6/data_MPR_20.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_13.png', 'MPR_Data_Directory_Target_6/figure_MPR_11.png', 'MPR_Data_Directory_Target_6/data_MPR_22.pkl', 'MPR_Data_Directory_Target_6/data_MPR_23.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_10.png', 'MPR_Data_Directory_Target_6/figure_MPR_5.png', 'MPR_Data_Directory_Target_6/figure_MPR_4.png', 'MPR_Data_Directory_Target_6/figure_MPR_6.png', 'MPR_Data_Directory_Target_6/figure_MPR_7.png', 'MPR_Data_Directory_Target_6/figure_MPR_3.png', 'MPR_Data_Directory_Target_6/figure_MPR_2.png', 'MPR_Data_Directory_Target_6/data_MPR_9.pkl', 'MPR_Data_Directory_Target_6/figure_MPR_0.png', 'MPR_Data_Directory_Target_6/figure_MPR_1.png', 'MPR_Data_Directory_Target_6/data_MPR_8.pkl']
# loaded ['visual_SNN_14.png', 'data_SNN_1.pkl', 'visual_SNN_5.png', 'data_SNN_9.pkl', 'data_SNN_13.pkl', 'data_SNN_10.pkl', 'visual_SNN_18.png', 'visual_SNN_1.png', 'visual_SNN_13.png', 'visual_SNN_6.png', 'visual_SNN_9.png', 'data_SNN_8.pkl', 'data_SNN_2.pkl', 'visual_SNN_7.png', 'visual_SNN_17.png', 'data_SNN_3.pkl', 'data_SNN_4.pkl', 'data_SNN_20.pkl', 'visual_SNN_19.png', 'visual_SNN_4.png', 'visual_SNN_10.png', 'data_SNN_11.pkl', 'data_SNN_5.pkl', 'visual_SNN_12.png', 'data_SNN_17.pkl', 'data_SNN_12.pkl', 'visual_SNN_11.png', 'data_SNN_22.pkl', 'data_SNN_19.pkl', 'data_SNN_23.pkl', 'visual_SNN_8.png', 'visual_SNN_15.png', 'data_SNN_14.pkl', 'data_SNN_16.pkl', 'data_SNN_6.pkl', 'visual_SNN_23.png', 'visual_SNN_3.png', 'data_SNN_15.pkl', 'visual_SNN_21.png', 'visual_SNN_20.png', 'data_SNN_7.pkl', 'visual_SNN_2.png', 'visual_SNN_16.png', 'visual_SNN_0.png', 'data_SNN_18.pkl', 'visual_SNN_22.png', 'data_SNN_0.pkl', 'data_SNN_21.pkl']
# 184

# %% [markdown]
# - Load optimized parameter sets
# - create a list with the fitting performance
# - Load "param_freq_target_X.csv"
# - Add the fitting performance.
# - save as "param_freq_target_X.csv"

# %%
for target_freq in [6, 10, 20, 60]:

    # Collect fitness entries from both parameter sets
    fitness_frames = []
    for parameter_set_file in ['optimized_frequencies', 'rand_init_optimization_results']:

        data_parameter_set = pd.read_csv(parameter_set_file + '.csv')
        # Select rows matching target_freq and keep 'fitness' as a DataFrame
        fitness = (data_parameter_set.loc[data_parameter_set['desired_frequency'] == target_freq, ['fitness']].reset_index(drop=True))
        fitness_frames.append(fitness)
    new_df = pd.concat(fitness_frames, axis=0, ignore_index=True)

    dataframe_file_name = '/Users/koksal/Documents/Projects/2024_EITN/followup/codes/MPR-SNN_Data_Validation/param_freq_target_'+variationvrvt+'_'+str(target_freq)+'.csv'

    df = pd.read_csv(dataframe_file_name)
    df.drop(columns=['Unnamed: 0'], inplace=True)
    df = pd.concat([df, new_df], axis=1)
    df.to_csv(dataframe_file_name)
    dataframe_file_name_2 = '/Users/koksal/Documents/Projects/2024_EITN/followup/codes/mpr-oscillations-snn/param_freq_target_'+variationvrvt+'_'+str(target_freq)+'.csv'
    df.to_csv(dataframe_file_name_2)

# %%
df.head()
